# %%
# tuple(): tuple is the ordered collection of objects enclosed within paranthesis
account_info = ('iob bank', 21221212, 'gla branch')
print(account_info)
# Out:
# ('iob bank', 21221212, 'gla branch')

# %%
# accessing the elements
tp = (22, 42, 'hello', 3.8)
# out = tp[0]  # index
out = out = tp[1:3]  # slicing range
print(out)
# Out:
# (42, 'hello')

# %%
ls = [10, 100]
print(ls, id(ls))
ls[0] = 'R'
print(ls, id(ls))
# Out:
# [10, 100] 1873679589184
# ['R', 100] 1873679589184

# %%
tp1 = (30, 34)
tp2 = (2, 100)
tp = tp1 + tp2
print(tp, type(tp))
# Out:
# (30, 34, 2, 100) <class 'tuple'>

# %%
# a = hello
print(a, type(a))
# Out:
# hello <class 'str'>

# %%
ls = (3, 4, 5)
ls[0] = 100
# print(out)
print(ls)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 2
#       1 ls = (3, 4, 5)
# ----> 2 ls[0] = 100
#       3 # print(out)
#       4 print(ls)
#
# TypeError: 'tuple' object does not support item assignment

# %%
k = (3, 'hello', 3.54)
# k[0] = 100  # tuple dosnt support the item assignment
del k[0]
print(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [10], line 4
#       1 k = (3, 'hello', 3.54)
#       2 # k[0] = 100  # tuple dosnt support the item assignment
# ----> 4 del k[0]
#       5 print(k)
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
ls = (4, 67, (3, 4), [3, 5])
ls[-1][0] = 100
print(ls)
# Out:
# (4, 67, (3, 4), [100, 5])
